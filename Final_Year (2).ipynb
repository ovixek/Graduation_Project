# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import tensorflow as tf

# %%
import os
import tensorflow as tf
from tensorflow.keras.applications import InceptionV3
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dropout,Input,Flatten,Dense,MaxPooling2D
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
BATCH_SIZE = 512
EPOCHS = 10

# %%
train_datagen = ImageDataGenerator(rescale = 1./255, rotation_range = 0.2,shear_range = 0.2,
    zoom_range = 0.2,width_shift_range = 0.2,
    height_shift_range = 0.2, validation_split = 0.2)

# %%
train_data= train_datagen.flow_from_directory(os.path.join('/content/drive/MyDrive/mrleyedataset/Train'), target_size=(80,80), batch_size=8,class_mode='categorical')
validation_data= train_datagen.flow_from_directory(os.path.join('/content/drive/MyDrive/mrleyedataset/Train'),
                                target_size = (80,80), batch_size = 8,
                                class_mode = 'categorical', subset='validation')
# Out:
# Found 84928 images belonging to 2 classes.
# Found 16985 images belonging to 2 classes.

# %%
test_datagen = ImageDataGenerator(rescale = 1./255)

test_data = test_datagen.flow_from_directory(os.path.join('/content/drive/MyDrive/mrleyedataset/Test'),
                                target_size=(80,80), batch_size = BATCH_SIZE, class_mode='categorical')
# Out:
# Found 5000 images belonging to 2 classes.

# %%
bmodel = InceptionV3(include_top = False, weights = 'imagenet',
                     input_tensor = Input(shape = (80,80,3)))
hmodel = bmodel.output
hmodel = Flatten()(hmodel)
hmodel = Dense(64, activation = 'relu')(hmodel)
hmodel = Dropout(0.5)(hmodel)
hmodel = Dense(2,activation = 'softmax')(hmodel)

model = Model(inputs = bmodel.input, outputs= hmodel)
for layer in bmodel.layers:
    layer.trainable = False
# Out:
# ...
# 87910968/87910968 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step

# %%
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)  │ (None, 80, 80, 3)      │              0 │ -                      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d (Conv2D)           │ (None, 39, 39, 32)     │            864 │ input_layer[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization       │ (None, 39, 39, 32)     │             96 │ conv2d[0][0]           │
# │ (BatchNormalization)      │                        │                │                        │
# ...

# %%
from tensorflow.keras.callbacks import ModelCheckpoint,EarlyStopping, ReduceLROnPlateau

# %%
earlystop = EarlyStopping(monitor = 'val_loss', patience = 7,
                          verbose= 3, restore_best_weights = True)


learning_rate = ReduceLROnPlateau(monitor= 'val_loss', patience=3, verbose= 3, )

callbacks = [earlystop, learning_rate]

# %%
model.compile(optimizer = 'Adam',
              loss = 'categorical_crossentropy',
              metrics = ['accuracy'])
model.fit(
train_data,
steps_per_epoch=train_data.samples // BATCH_SIZE,
validation_data=validation_data,
validation_steps=validation_data.samples//BATCH_SIZE,
epochs=EPOCHS,
)
# Out:
# Epoch 1/10
# /usr/local/lib/python3.10/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 994s 6s/step - accuracy: 0.7965 - loss: 0.4847 - val_accuracy: 0.8409 - val_loss: 0.4510
# Epoch 2/10
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 169s 1s/step - accuracy: 0.8812 - loss: 0.2855 - val_accuracy: 0.9205 - val_loss: 0.2204
# Epoch 3/10
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 173s 1s/step - accuracy: 0.8922 - loss: 0.2733 - val_accuracy: 0.8977 - val_loss: 0.2446
# Epoch 4/10
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 153s 932ms/step - accuracy: 0.9094 - loss: 0.2454 - val_accuracy: 0.8902 - val_loss: 0.2429
# Epoch 5/10
# ...

# %%
model_path = "/content/drive/MyDrive/final_model.h5"
model.save(model_path)
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
model_path = "/content/drive/MyDrive/final_model_1.keras"
model.save(model_path)  # Automatically saves in the Keras format

# %%
weights_path = "/content/drive/MyDrive/model_weights.weights.h5"
model.save_weights(weights_path)

# %%
# Evaluate on validation data
loss_vr, acc_vr = model.evaluate(validation_data, verbose=1)
print(f"Validation Accuracy: {acc_vr}")
print(f"Validation Loss: {loss_vr}")
# Out:
# 1848/2124 ━━━━━━━━━━━━━━━━━━━━ 3:07 681ms/step - accuracy: 0.9235 - loss: 0.1848
